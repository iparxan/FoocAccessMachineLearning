# %%
import pandas as pd
import numpy as np
import os

# %%
# read the data
file_path="Resources/FoodAccessResearchAtlas2019.csv"
foodAccessResearchAtlas=pd.read_csv(file_path)
foodAccessResearchAtlas.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# ...

# %%
foodAccessResearchAtlas.columns.tolist()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lapophalfshare',
#  'lalowihalf',
#  'lalowihalfshare',
#  'lakidshalf',
#  'lakidshalfshare',
#  'laseniorshalf',
#  'laseniorshalfshare',
#  'lawhitehalf',
#  'lawhitehalfshare',
#  'lablackhalf',
#  'lablackhalfshare',
#  'laasianhalf',
#  'laasianhalfshare',
#  'lanhopihalf',
#  'lanhopihalfshare',
#  'laaianhalf',
#  'laaianhalfshare',
#  'laomultirhalf',
#  'laomultirhalfshare',
#  'lahisphalf',
# ...

# %%
df=pd.DataFrame(foodAccessResearchAtlas)
df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# ...

# %%
california_foodAccessResearchAtlas=df.loc[df["State"] == "California"]
california_foodAccessResearchAtlas.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
california_foodAccessResearchAtlas.dtypes
# Out:
# CensusTract        int64
# State             object
# County            object
# Urban              int64
# Pop2010            int64
#                   ...
# TractAIAN        float64
# TractOMultir     float64
# TractHispanic    float64
# TractHUNV        float64
# TractSNAP        float64
# Length: 147, dtype: object

# %%
len(california_foodAccessResearchAtlas.index)
# Out:
# 8024

# %%
california_foodAccessResearchAtlas.tail(10)
# Out:
#        CensusTract       State       County  Urban  Pop2010  OHU2010  \
# 11565   6115040303  California  Yuba County      1     6555     1969
# 11566   6115040400  California  Yuba County      1     5538     1625
# 11567   6115040500  California  Yuba County      1     4111     1220
# 11568   6115040600  California  Yuba County      1     6130     1846
# 11569   6115040700  California  Yuba County      0    10879     3320
# 11570   6115040800  California  Yuba County      0     4233     1492
# 11571   6115040901  California  Yuba County      0     2783      968
# 11572   6115040902  California  Yuba County      0     1737      385
# 11573   6115041000  California  Yuba County      0     7357     2802
# 11574   6115041100  California  Yuba County      0     4941     2105
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 11565                  0      21.0      0.32                  0  ...
# ...

# %%
clean_df1 = california_foodAccessResearchAtlas.drop([col for col in california_foodAccessResearchAtlas.columns if 'share' in col],axis=1)
clean_df1.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df2=clean_df1.drop([col for col in clean_df1.columns if "Kids"  in col],axis=1)
clean_df2.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df2.columns.tolist()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lakidshalf',
#  'laseniorshalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lakids1',
#  'laseniors1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
# ...

# %%
clean_df3=clean_df2.drop([col for col in clean_df2.columns if "kids" in col],axis=1)
clean_df3.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df4=clean_df3.drop([col for col in clean_df3.columns if "seniors" in col],axis=1)
clean_df4.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df5=clean_df4.drop([col for col in clean_df4.columns if "Seniors" in col],axis=1)
clean_df5.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractLOWI  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df5.columns.tolist()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
#  'lalowi10',
#  'lawhite10',
#  'lablack10',
#  'laasian10',
# ...

# %%
FoodAccess_2019_col_list=clean_df5.columns.tolist()
FoodAccess_2019_col_list
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
#  'lalowi10',
#  'lawhite10',
#  'lablack10',
#  'laasian10',
# ...

# %%
col_list2019=pd.DataFrame(FoodAccess_2019_col_list)
col_list2019
# Out:
#                 0
# 0     CensusTract
# 1           State
# 2          County
# 3           Urban
# 4         Pop2010
# ..            ...
# 80      TractAIAN
# 81   TractOMultir
# 82  TractHispanic
# 83      TractHUNV
# 84      TractSNAP
#
# [85 rows x 1 columns]

# %%
clean_df5.isnull().sum().sort_values(ascending = False)
# Out:
# laaian20         7914
# lasnap20         7914
# lapop20          7914
# lalowi20         7914
# lawhite20        7914
#                  ...
# LATracts_half       0
# LATracts1           0
# LATracts10          0
# LATracts20          0
# TractSNAP           0
# Length: 85, dtype: int64

# %%
def missing_values_table(clean_df5):
    mis_val = clean_df5.isnull().sum()
    mis_val_percent = 100 * clean_df5.isnull().sum() / len(clean_df5)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(clean_df5.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(clean_df5)
# Out:
# Your selected dataframe has 85 columns.
# There are 53 columns that have missing values.
#                     Missing Values  % of Total Values
# lasnap20                      7914               98.6
# laaian20                      7914               98.6
# lapop20                       7914               98.6
# lawhite20                     7914               98.6
# lablack20                     7914               98.6
# laasian20                     7914               98.6
# lanhopi20                     7914               98.6
# lalowi20                      7914               98.6
# lahisp20                      7914               98.6
# lahunv20                      7914               98.6
# laomultir20                   7914               98.6
# lahisp10                      7703               96.0
# laasian10                     7703               96.0
# lapop10                       7703               96.0
# lalowi10                      7703               96.0
# ...

# %%
len(clean_df5)
# Out:
# 8024

# %%
import os  
os.makedirs('Resources', exist_ok=True)  
col_list2019.to_csv('Resources/col_list2019.csv')

# %%
clean_df5.to_csv("Resources/FoodAccess2019_clean.csv")
