# %%
import pandas as pd
import numpy as np
import os

# %%
# read the data
file_path="Resources/FoodAccess2019_clean.csv"
foodAccess19_clean=pd.read_csv(file_path, index_col=[0])
foodAccess19_clean.head(20)
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
# 3556   6001400600  California  Alameda County      1     1571      690
# 3557   6001400700  California  Alameda County      1     4206     1755
# 3558   6001400800  California  Alameda County      1     3594     1567
# 3559   6001400900  California  Alameda County      1     2302     1019
# 3560   6001401000  California  Alameda County      1     5678     2354
# 3561   6001401100  California  Alameda County      1     4156     2007
# 3562   6001401200  California  Alameda County      1     2416     1216
# ...

# %%
foodAccess19_df=pd.DataFrame(foodAccess19_clean)

# %%
foodAccess19_df.dtypes
# Out:
# CensusTract        int64
# State             object
# County            object
# Urban              int64
# Pop2010            int64
#                   ...
# TractAIAN        float64
# TractOMultir     float64
# TractHispanic    float64
# TractHUNV        float64
# TractSNAP        float64
# Length: 85, dtype: object

# %%
list(foodAccess19_df.isnull().count())
# Out:
# [8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024,
#  8024]

# %%
len(foodAccess19_df)
# Out:
# 8024

# %%
#alternative way
foodAccess19All_df=foodAccess19_df.copy()
foodAccess19All_df.head()
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 3551   6001400100  California  Alameda County      1     2937     1314
# 3552   6001400200  California  Alameda County      1     1974      856
# 3553   6001400300  California  Alameda County      1     4865     2418
# 3554   6001400400  California  Alameda County      1     3703     1779
# 3555   6001400500  California  Alameda County      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3551                  0       2.0      0.07                  0  ...
# 3552                  0      70.0      3.55                  0  ...
# 3553                  0      40.0      0.82                  0  ...
# 3554                  0      33.0      0.89                  0  ...
# 3555                  0     126.0      3.58                  0  ...
#
#       TractLOWI  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
len(FoodAccess2019HPAll_df)
# Out:
# 8024

# %%
FoodAccess2019HPAll_df2 =FoodAccess2019HPAll_df.dropna(axis=1)

# %%
FoodAccess2019HPAll_df2
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# 8019   6115040800  California     Yuba County      0     4233     1492
# 8020   6115040901  California     Yuba County      0     2783      968
# 8021   6115040902  California     Yuba County      0     1737      385
# 8022   6115041000  California     Yuba County      0     7357     2802
# 8023   6115041100  California     Yuba County      0     4941     2105
#
#       GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# ...

# %%
# read the housing price zip data
file_path="Resources/clean_census_2019.csv"
clean_house_price=pd.read_csv(file_path, index_col=[0])
clean_house_price.head()
# Out:
#    Estimate_Median_value_(dollars)  Margin_of_Error_Median_value_(dollars)  \
# 1                          1197900                                   68223
# 2                          1385400                                  191210
# 3                          1053200                                  121286
# 4                          1111600                                  117913
# 5                           813800                                  105558
#
#    CensusTract                           Geographic_Area_Name
# 1   6001400100  Census Tract 4001, Alameda County, California
# 2   6001400200  Census Tract 4002, Alameda County, California
# 3   6001400300  Census Tract 4003, Alameda County, California
# 4   6001400400  Census Tract 4004, Alameda County, California
# 5   6001400500  Census Tract 4005, Alameda County, California

# %%
len(clean_house_price)
# Out:
# 7689

# %%
clean_house_price=pd.DataFrame(clean_house_price)
clean_house_price.head()
# Out:
#    Estimate_Median_value_(dollars)  Margin_of_Error_Median_value_(dollars)  \
# 1                          1197900                                   68223
# 2                          1385400                                  191210
# 3                          1053200                                  121286
# 4                          1111600                                  117913
# 5                           813800                                  105558
#
#    CensusTract                           Geographic_Area_Name
# 1   6001400100  Census Tract 4001, Alameda County, California
# 2   6001400200  Census Tract 4002, Alameda County, California
# 3   6001400300  Census Tract 4003, Alameda County, California
# 4   6001400400  Census Tract 4004, Alameda County, California
# 5   6001400500  Census Tract 4005, Alameda County, California

# %%
clean_house_price.columns
# Out:
# Index(['Estimate_Median_value_(dollars)',
#        'Margin_of_Error_Median_value_(dollars)', 'CensusTract',
#        'Geographic_Area_Name'],
#       dtype='object')

# %%
housing_price=clean_house_price.filter(['CensusTract','Estimate_Median_value_(dollars)',
       'Margin_of_Error_Median_value_(dollars)'], axis=1)
housing_price
# Out:
#       CensusTract  Estimate_Median_value_(dollars)  \
# 1      6001400100                          1197900
# 2      6001400200                          1385400
# 3      6001400300                          1053200
# 4      6001400400                          1111600
# 5      6001400500                           813800
# ...           ...                              ...
# 8052   6115040700                           301200
# 8053   6115040800                           273300
# 8054   6115040901                           222100
# 8056   6115041000                           350400
# 8057   6115041100                           256200
#
#       Margin_of_Error_Median_value_(dollars)
# 1                                      68223
# 2                                     191210
# 3                                     121286
# 4                                     117913
# 5                                     105558
# ...                                      ...
# ...

# %%
#alternative merge
FoodAccess2019HPAll_df_new=pd.merge(FoodAccess2019HPAll_df2, housing_price, how="left", on=["CensusTract"],validate=None)
FoodAccess2019HPAll_df_new.head(10)
# Out:
#    CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0   6001400100  California  Alameda County      1     2937     1314
# 1   6001400200  California  Alameda County      1     1974      856
# 2   6001400300  California  Alameda County      1     4865     2418
# 3   6001400400  California  Alameda County      1     3703     1779
# 4   6001400500  California  Alameda County      1     3517     1578
# 5   6001400600  California  Alameda County      1     1571      690
# 6   6001400700  California  Alameda County      1     4206     1755
# 7   6001400800  California  Alameda County      1     3594     1567
# 8   6001400900  California  Alameda County      1     2302     1019
# 9   6001401000  California  Alameda County      1     5678     2354
#
#    GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# 0                  0                  0                     0
# 1                  0                  0                     0
# ...

# %%
FoodAccess2019HPAll_df3=FoodAccess2019HPAll_df_new.astype({"Estimate_Median_value_(dollars)": float, "Margin_of_Error_Median_value_(dollars)": float},errors='ignore')
FoodAccess2019HPAll_df3
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# 8019   6115040800  California     Yuba County      0     4233     1492
# 8020   6115040901  California     Yuba County      0     2783      968
# 8021   6115040902  California     Yuba County      0     1737      385
# 8022   6115041000  California     Yuba County      0     7357     2802
# 8023   6115041100  California     Yuba County      0     4941     2105
#
#       GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# ...

# %%
FoodAccess2019HPAll_df3.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'Urban', 'Pop2010', 'OHU2010',
#        'GroupQuartersFlag', 'LILATracts_1And10', 'LILATracts_halfAnd10',
#        'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag',
#        'LowIncomeTracts', 'PovertyRate', 'LA1and10', 'LAhalfand10', 'LA1and20',
#        'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20',
#        'LATractsVehicle_20', 'TractLOWI', 'TractWhite', 'TractBlack',
#        'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir',
#        'TractHispanic', 'TractHUNV', 'TractSNAP',
#        'Estimate_Median_value_(dollars)',
#        'Margin_of_Error_Median_value_(dollars)'],
#       dtype='object')

# %%
FoodAccess2019HPAll_df3.dtypes
# Out:
# CensusTract                                 int64
# State                                      object
# County                                     object
# Urban                                       int64
# Pop2010                                     int64
# OHU2010                                     int64
# GroupQuartersFlag                           int64
# LILATracts_1And10                           int64
# LILATracts_halfAnd10                        int64
# LILATracts_1And20                           int64
# LILATracts_Vehicle                          int64
# HUNVFlag                                    int64
# LowIncomeTracts                             int64
# PovertyRate                               float64
# LA1and10                                    int64
# LAhalfand10                                 int64
# LA1and20                                    int64
# LATracts_half                               int64
# LATracts1                                   int64
# ...

# %%
from scipy.stats import zscore

# %%
FoodAccess2019HPAll_df4=FoodAccess2019HPAll_df3.dropna()
FoodAccess2019HPAll_df4
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# 8018   6115040700  California     Yuba County      0    10879     3320
# 8019   6115040800  California     Yuba County      0     4233     1492
# 8020   6115040901  California     Yuba County      0     2783      968
# 8022   6115041000  California     Yuba County      0     7357     2802
# 8023   6115041100  California     Yuba County      0     4941     2105
#
#       GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# ...

# %%
list(FoodAccess2019HPAll_df3["Estimate_Median_value_(dollars)"])
# Out:
# [1197900.0,
#  1385400.0,
#  1053200.0,
#  1111600.0,
#  813800.0,
#  825700.0,
#  702500.0,
#  697000.0,
#  774700.0,
#  728800.0,
#  889800.0,
#  873800.0,
#  783100.0,
#  546700.0,
#  561200.0,
#  577100.0,
#  585400.0,
#  552300.0,
#  684100.0,
#  610800.0,
#  720000.0,
#  557400.0,
#  673400.0,
#  791200.0,
#  nan,
#  455400.0,
#  608200.0,
#  503200.0,
#  593200.0,
#  664100.0,
#  464500.0,
#  549000.0,
#  425900.0,
#  724700.0,
#  1052700.0,
#  664700.0,
#  629600.0,
#  801500.0,
#  682700.0,
#  1220500.0,
#  1567400.0,
#  995000.0,
#  1242200.0,
#  1001200.0,
#  1008300.0,
#  1044200.0,
#  870300.0,
#  880200.0,
#  1037200.0,
#  1358800.0,
#  888900.0,
#  682000.0,
#  585900.0,
#  498800.0,
#  573700.0,
#  687900.0,
#  563200.0,
#  484900.0,
#  463300.0,
#  434000.0,
#  533900.0,
#  571400.0,
#  565500.0,
#  531500.0,
#  538000.0,
#  453500.0,
#  594700.0,
#  468800.0,
#  481200.0,
#  562900.0,
#  834200.0,
#  819500.0,
#  769200.0,
#  534800.0,
#  448100.0,
#  530400.0,
# ...

# %%
FoodAccess2019HPAll_df4=FoodAccess2019HPAll_df3.dropna()
FoodAccess2019HPAll_df4
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# 8018   6115040700  California     Yuba County      0    10879     3320
# 8019   6115040800  California     Yuba County      0     4233     1492
# 8020   6115040901  California     Yuba County      0     2783      968
# 8022   6115041000  California     Yuba County      0     7357     2802
# 8023   6115041100  California     Yuba County      0     4941     2105
#
#       GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# ...

# %%
FoodAccess2019HPAll_df4["ZScore_EstMedVal"]=zscore(FoodAccess2019HPAll_df4["Estimate_Median_value_(dollars)"])
FoodAccess2019HPAll_df4
# Out:
# C:\ProgramData\Anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# ...

# %%
FoodAccess2019HPAll_df4.dtypes
# Out:
# CensusTract                                 int64
# State                                      object
# County                                     object
# Urban                                       int64
# Pop2010                                     int64
# OHU2010                                     int64
# GroupQuartersFlag                           int64
# LILATracts_1And10                           int64
# LILATracts_halfAnd10                        int64
# LILATracts_1And20                           int64
# LILATracts_Vehicle                          int64
# HUNVFlag                                    int64
# LowIncomeTracts                             int64
# PovertyRate                               float64
# LA1and10                                    int64
# LAhalfand10                                 int64
# LA1and20                                    int64
# LATracts_half                               int64
# LATracts1                                   int64
# ...

# %%
FoodAccess2019HPAll_df4=FoodAccess2019HPAll_df4.drop(columns=["Estimate_Median_value_(dollars)","Margin_of_Error_Median_value_(dollars)"])
FoodAccess2019HPAll_df4
# Out:
#       CensusTract       State          County  Urban  Pop2010  OHU2010  \
# 0      6001400100  California  Alameda County      1     2937     1314
# 1      6001400200  California  Alameda County      1     1974      856
# 2      6001400300  California  Alameda County      1     4865     2418
# 3      6001400400  California  Alameda County      1     3703     1779
# 4      6001400500  California  Alameda County      1     3517     1578
# ...           ...         ...             ...    ...      ...      ...
# 8018   6115040700  California     Yuba County      0    10879     3320
# 8019   6115040800  California     Yuba County      0     4233     1492
# 8020   6115040901  California     Yuba County      0     2783      968
# 8022   6115041000  California     Yuba County      0     7357     2802
# 8023   6115041100  California     Yuba County      0     4941     2105
#
#       GroupQuartersFlag  LILATracts_1And10  LILATracts_halfAnd10  \
# ...

# %%
FoodAccess2019HPAll_df5=FoodAccess2019HPAll_df4.drop(columns=["State"], axis=1)
FoodAccess2019HPAll_df5
# Out:
#       CensusTract          County  Urban  Pop2010  OHU2010  GroupQuartersFlag  \
# 0      6001400100  Alameda County      1     2937     1314                  0
# 1      6001400200  Alameda County      1     1974      856                  0
# 2      6001400300  Alameda County      1     4865     2418                  0
# 3      6001400400  Alameda County      1     3703     1779                  0
# 4      6001400500  Alameda County      1     3517     1578                  0
# ...           ...             ...    ...      ...      ...                ...
# 8018   6115040700     Yuba County      0    10879     3320                  0
# 8019   6115040800     Yuba County      0     4233     1492                  0
# 8020   6115040901     Yuba County      0     2783      968                  0
# 8022   6115041000     Yuba County      0     7357     2802                  0
# 8023   6115041100     Yuba County      0     4941     2105                  0
#
# ...

# %%
import os  
os.makedirs('Resources/', exist_ok=True)  
FoodAccess2019HPAll_df5.to_csv('Resources/FoodAccess2019CensusTractAll.csv', index=False)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
FoodAccess2019HPAll_df.hist(bins=50, figsize=(20,15))
plt.show()
