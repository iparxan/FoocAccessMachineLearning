# %%
import pandas as pd
import numpy as np
import os

# %%
# read the data
file_path="Resources/FoodAccess2015.csv"
foodAccess15=pd.read_csv(file_path)
foodAccess15.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractSeniors  TractWhite  \
# 0         0  0.000000                  0  ...           221        1622
# 1       181  0.083410                  0  ...           214         888
# 2         0  0.000000                  0  ...           439        2576
# 3         0  0.000000                  0  ...           904        4086
# 4       181  0.016812                  0  ...          1126        8666
#
# ...

# %% [raw]
# foodAccess15.columns.tolist()

# %%
df=pd.DataFrame(foodAccess15)
df.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractSeniors  TractWhite  \
# 0         0  0.000000                  0  ...           221        1622
# 1       181  0.083410                  0  ...           214         888
# 2         0  0.000000                  0  ...           439        2576
# 3         0  0.000000                  0  ...           904        4086
# 4       181  0.016812                  0  ...          1126        8666
#
# ...

# %%
california_FoodAccess15=df.loc[df["State"] == "California"]
california_FoodAccess15.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558           634        2161         142         456           9          4
# ...

# %%
california_FoodAccess15.dtypes
# Out:
# CensusTract       int64
# State            object
# County           object
# Urban             int64
# POP2010           int64
#                   ...
# TractAIAN         int64
# TractOMultir      int64
# TractHispanic     int64
# TractHUNV         int64
# TractSNAP         int64
# Length: 147, dtype: object

# %%
len(california_FoodAccess15.index)
# Out:
# 8044

# %%
california_FoodAccess15.tail(10)
# Out:
#        CensusTract       State County  Urban  POP2010  OHU2010  \
# 11592   6115040303  California   Yuba      1     6555     1969
# 11593   6115040400  California   Yuba      1     5538     1625
# 11594   6115040500  California   Yuba      1     4111     1220
# 11595   6115040600  California   Yuba      1     6130     1846
# 11596   6115040700  California   Yuba      0    10879     3320
# 11597   6115040800  California   Yuba      0     4233     1492
# 11598   6115040901  California   Yuba      0     2783      968
# 11599   6115040902  California   Yuba      0     1737      385
# 11600   6115041000  California   Yuba      0     7357     2802
# 11601   6115041100  California   Yuba      0     4941     2105
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 11592                  0        21  0.003204                  0  ...
# 11593                  0         1  0.000181                  1  ...
# ...

# %%
clean_df1 = california_FoodAccess15.drop([col for col in california_FoodAccess15.columns if 'share' in col],axis=1)
clean_df1.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558           634        2161         142         456           9          4
# ...

# %%
clean_df2=clean_df1.drop([col for col in clean_df1.columns if "Kids"  in col],axis=1)
clean_df2.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558           634        2161         142         456           9          4
# ...

# %%
clean_df2.columns.tolist()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'POP2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lakidshalf',
#  'laseniorshalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lakids1',
#  'laseniors1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
# ...

# %%
clean_df3=clean_df2.drop([col for col in clean_df2.columns if "kids" in col],axis=1)
clean_df3.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558           634        2161         142         456           9          4
# ...

# %%
clean_df4=clean_df3.drop([col for col in clean_df3.columns if "seniors" in col],axis=1)
clean_df4.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558           634        2161         142         456           9          4
# ...

# %%
clean_df5=clean_df4.drop([col for col in clean_df4.columns if "Seniors" in col],axis=1)
clean_df5.head()
# Out:
#       CensusTract       State   County  Urban  POP2010  OHU2010  \
# 3558   6001400100  California  Alameda      1     2937     1314
# 3559   6001400200  California  Alameda      1     1974      856
# 3560   6001400300  California  Alameda      1     4865     2418
# 3561   6001400400  California  Alameda      1     3703     1779
# 3562   6001400500  California  Alameda      1     3517     1578
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 3558                  0         2  0.000681                  0  ...
# 3559                  0        70  0.035461                  0  ...
# 3560                  0        40  0.008222                  0  ...
# 3561                  0        33  0.008912                  0  ...
# 3562                  0       126  0.035826                  0  ...
#
#       TractLOWI  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 3558        173        2161         142         456           9          4
# ...

# %%
clean_df5.tail(10)
# Out:
#        CensusTract       State County  Urban  POP2010  OHU2010  \
# 11592   6115040303  California   Yuba      1     6555     1969
# 11593   6115040400  California   Yuba      1     5538     1625
# 11594   6115040500  California   Yuba      1     4111     1220
# 11595   6115040600  California   Yuba      1     6130     1846
# 11596   6115040700  California   Yuba      0    10879     3320
# 11597   6115040800  California   Yuba      0     4233     1492
# 11598   6115040901  California   Yuba      0     2783      968
# 11599   6115040902  California   Yuba      0     1737      385
# 11600   6115041000  California   Yuba      0     7357     2802
# 11601   6115041100  California   Yuba      0     4941     2105
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 11592                  0        21  0.003204                  0  ...
# 11593                  0         1  0.000181                  1  ...
# ...

# %%
clean_df5.columns.tolist()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'POP2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
#  'lalowi10',
#  'lawhite10',
#  'lablack10',
#  'laasian10',
# ...

# %%
FoodAccess_2015_col_list=clean_df5.columns.tolist()
FoodAccess_2015_col_list
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'POP2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lalowihalf',
#  'lawhitehalf',
#  'lablackhalf',
#  'laasianhalf',
#  'lanhopihalf',
#  'laaianhalf',
#  'laomultirhalf',
#  'lahisphalf',
#  'lahunvhalf',
#  'lasnaphalf',
#  'lapop1',
#  'lalowi1',
#  'lawhite1',
#  'lablack1',
#  'laasian1',
#  'lanhopi1',
#  'laaian1',
#  'laomultir1',
#  'lahisp1',
#  'lahunv1',
#  'lasnap1',
#  'lapop10',
#  'lalowi10',
#  'lawhite10',
#  'lablack10',
#  'laasian10',
# ...

# %%
col_list2015=pd.DataFrame(FoodAccess_2015_col_list)
col_list2015
# Out:
#                 0
# 0     CensusTract
# 1           State
# 2          County
# 3           Urban
# 4         POP2010
# ..            ...
# 80      TractAIAN
# 81   TractOMultir
# 82  TractHispanic
# 83      TractHUNV
# 84      TractSNAP
#
# [85 rows x 1 columns]

# %%
clean_df5.isnull().sum().sort_values(ascending = False)
# Out:
# CensusTract           0
# lalowi10              0
# lahunv10              0
# lahisp10              0
# laomultir10           0
#                      ..
# LAPOP1_20             0
# LAPOP05_10            0
# LAPOP1_10             0
# LATractsVehicle_20    0
# TractSNAP             0
# Length: 85, dtype: int64

# %%
def missing_values_table(clean_df5):
    mis_val = clean_df5.isnull().sum()
    mis_val_percent = 100 * clean_df5.isnull().sum() / len(clean_df5)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(clean_df5.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(clean_df5)
# Out:
# Your selected dataframe has 85 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
len(clean_df5)
# Out:
# 8044

# %%
import os  
os.makedirs('Resources/', exist_ok=True)  
col_list2015.to_csv('Resources/col_list2015.csv')

# %%
clean_df5=clean_df5.drop(columns=["State"])

# %%
clean_df5.head()
# Out:
#       CensusTract   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 3558   6001400100  Alameda      1     2937     1314                  0
# 3559   6001400200  Alameda      1     1974      856                  0
# 3560   6001400300  Alameda      1     4865     2418                  0
# 3561   6001400400  Alameda      1     3703     1779                  0
# 3562   6001400500  Alameda      1     3517     1578                  0
#
#       NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  ...  \
# 3558         2  0.000681                  0                     0  ...
# 3559        70  0.035461                  0                     0  ...
# 3560        40  0.008222                  0                     0  ...
# 3561        33  0.008912                  0                     0  ...
# 3562       126  0.035826                  0                     0  ...
#
#       TractLOWI  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
clean_df5.to_csv("Resources/FoodAccess2015_clean.csv", index=False)

# %%
foodAccess2015_df=clean_df5.copy()
foodAccess2015_df.head()
# Out:
#       CensusTract   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 3558   6001400100  Alameda      1     2937     1314                  0
# 3559   6001400200  Alameda      1     1974      856                  0
# 3560   6001400300  Alameda      1     4865     2418                  0
# 3561   6001400400  Alameda      1     3703     1779                  0
# 3562   6001400500  Alameda      1     3517     1578                  0
#
#       NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  ...  \
# 3558         2  0.000681                  0                     0  ...
# 3559        70  0.035461                  0                     0  ...
# 3560        40  0.008222                  0                     0  ...
# 3561        33  0.008912                  0                     0  ...
# 3562       126  0.035826                  0                     0  ...
#
#       TractLOWI  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...
